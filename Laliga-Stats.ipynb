# %%
import pandas as pd

# %% [markdown]
# # Q1  Read the data set and replace dashes with 0 to make sure you can perform arithmetic operations on the data. (5 points)

# %%
df = pd.read_csv(r'C:\E Drive\Mixed Materials\AI-ML\PGPM-GreatLakes\Labs\Assignment 3-Stats\Laliga.csv',index_col = 'Pos' )
df.replace('-','0',inplace= True)
# For verifying:
# df.where(df == '-')
# df['GamesDrawn'].unique()
df.head(10)
# Out:
#                 Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# Pos
# 1        Real Madrid       86   4385        2762     1647        552
# 2          Barcelona       86   4262        2762     1581        573
# 3    Atletico Madrid       80   3442        2614     1241        598
# 4           Valencia       82   3386        2664     1187        616
# 5    Athletic Bilbao       86   3368        2762     1209        633
# 6            Sevilla       73   2819        2408      990        531
# 7           Espanyol       82   2792        2626      948        608
# 8      Real Sociedad       70   2573        2302      864        577
# 9           Zaragoza       58   2109        1986      698        522
# 10        Real Betis       51   1884        1728      606        440
#
#     GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# Pos
# 1         563     5947         3140       33        23     8      8     3
# ...

# %% [markdown]
# # Q2 Print all the teams which have started playing between 1930-1980. (5 points)

# %%
df[df['Debut'].map(lambda debut: int(debut.split('-')[0])).between(1930,1980)]['Team']
# Out:
# Pos
# 4                Valencia
# 6                 Sevilla
# 9                Zaragoza
# 10             Real Betis
# 11    Deportivo La Coruna
# 12             Celta Vigo
# 13             Valladolid
# 15         Sporting Gijon
# 16                Osasuna
# 17                 Malaga
# 18                 Oviedo
# 19               Mallorca
# 20             Las Palmas
# 22                Granada
# 23         Rayo Vallecano
# 24                  Elche
# 26               Hercules
# 27               Tenerife
# 28                 Murcia
# 29                 Alaves
# 30                Levante
# 31              Salamanca
# 32               Sabadell
# 33                  Cadiz
# 35              Castellon
# 38                Cordoba
# 40             Recreativo
# 41              Burgos CF
# 42             Pontevedra
# 47              Gimnastic
# 50               Alcoyano
# 51                   Jaen
# 53             AD Almeria
# 55                 Lleida
# 58                 Condal
# ...

# %%
df[(df['Debut'] >= '1930') & (df['Debut'] <= '1980')].loc[:,['Team']]
# Out:
#                     Team
# Pos
# 4               Valencia
# 6                Sevilla
# 9               Zaragoza
# 10            Real Betis
# 11   Deportivo La Coruna
# 12            Celta Vigo
# 13            Valladolid
# 15        Sporting Gijon
# 16               Osasuna
# 17                Malaga
# 18                Oviedo
# 19              Mallorca
# 20            Las Palmas
# 22               Granada
# 23        Rayo Vallecano
# 24                 Elche
# 26              Hercules
# 27              Tenerife
# 28                Murcia
# 29                Alaves
# 30               Levante
# 31             Salamanca
# 32              Sabadell
# 33                 Cadiz
# 35             Castellon
# 38               Cordoba
# 40            Recreativo
# 41             Burgos CF
# 42            Pontevedra
# 47             Gimnastic
# 50              Alcoyano
# 51                  Jaen
# 53            AD Almeria
# 55                Lleida
# 58                Condal
# ...

# %% [markdown]
# # Q3 Print the list of teams which came Top 5 in terms of points (5 points)

# %%
df[(df.Points.notnull())].loc[:,['Team','Points']].head(5)
# Out:
#                 Team Points
# Pos
# 1        Real Madrid   4385
# 2          Barcelona   4262
# 3    Atletico Madrid   3442
# 4           Valencia   3386
# 5    Athletic Bilbao   3368

# %% [markdown]
# # Q4. Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences. Using the same function, find the team which has maximum and minimum goal difference. (5 points)

# %%
# Convert GoalsFor and GoalsAgainst cols as int type since they are type as object and cannot suport '/
df['GoalsFor'] = df['GoalsFor'].astype('int64')
df['GoalsAgainst'] = df['GoalsAgainst'].astype('int64')

# %%
# write a function for counting the goal Difference
def Goal_diff_count(x):
    for goal_diff in x:
        df['Goal_differences'] = df['GoalsFor'] - df['GoalsAgainst']

# %%
#Fx calling.
Goal_diff_count(df['Team'])
df.head(2)
# Out:
#             Team  Seasons Points GamesPlayed GamesWon GamesDrawn GamesLost  \
# Pos
# 1    Real Madrid       86   4385        2762     1647        552       563
# 2      Barcelona       86   4262        2762     1581        573       608
#
#      GoalsFor  GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth   T  \
# Pos
# 1        5947          3140       33        23     8      8     3     4  79
# 2        5900          3114       25        25    12     12     4     6  83
#
#     Debut Since/LastApp  BestPosition  Goal_differences
# Pos
# 1    1929          1929             1              2807
# 2    1929          1929             1              2786

# %%
# using same function for counting the goal Difference with max and min values for the team.
def Goal_diff_count(x):
   
        df1 =  df[['Team','Goal_differences']].groupby('Goal_differences').max()
        print (df1.head(1))
        print (df1.tail(1))

# %%
#calling fx for printing team values
Goal_diff_count(df['Team'])
# Out:
#                               Team
# Goal_differences
# -525              Racing Santander
#                          Team
# Goal_differences
# 2807              Real Madrid

# %%
df.head()
# Out:
#                 Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# Pos
# 1        Real Madrid       86   4385        2762     1647        552
# 2          Barcelona       86   4262        2762     1581        573
# 3    Atletico Madrid       80   3442        2614     1241        598
# 4           Valencia       82   3386        2664     1187        616
# 5    Athletic Bilbao       86   3368        2762     1209        633
#
#     GamesLost  GoalsFor  GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# Pos
# 1         563      5947          3140       33        23     8      8     3
# 2         608      5900          3114       25        25    12     12     4
# 3         775      4534          3309       10         8    16      9     7
# 4         861      4398          3469        6         6    10     11    10
# 5         920      4631          3700        8         7    10      5     8
#
#     Sixth   T    Debut Since/LastApp  BestPosition  Goal_differences
# Pos
# ...

# %% [markdown]
# # Q5. Create a new column with name “Winning Percent” and append it to the data set (5 points)
#
# Percentage of Winning = (GamesWon / GamesPlayed)*100
#
# If there are any numerical error, replace it with 0%

# %%
# Convert GamesWon and GamesPlayed cols as int type since they are type as object and cannot suport '/'
df['GamesPlayed'] = df['GamesPlayed'].astype('int64')
df['GamesWon'] = df['GamesWon'].astype('int64')

#Create new col as in Question and filled with 0 values.

df['Winning Percent'] = df['GamesWon']/df ['GamesPlayed']  *100
df['Winning Percent'].fillna(0)
df.columns
# Out:
# Index(['Team', 'Seasons', 'Points', 'GamesPlayed', 'GamesWon', 'GamesDrawn',
#        'GamesLost', 'GoalsFor', 'GoalsAgainst', 'Champion', 'Runner-up',
#        'Third', 'Fourth', 'Fifth', 'Sixth', 'T', 'Debut', 'Since/LastApp',
#        'BestPosition', 'Goal_differences', 'Winning Percent'],
#       dtype='object')

# %%
df.head()
# Out:
#                 Team  Seasons Points  GamesPlayed  GamesWon GamesDrawn  \
# Pos
# 1        Real Madrid       86   4385         2762      1647        552
# 2          Barcelona       86   4262         2762      1581        573
# 3    Atletico Madrid       80   3442         2614      1241        598
# 4           Valencia       82   3386         2664      1187        616
# 5    Athletic Bilbao       86   3368         2762      1209        633
#
#     GamesLost  GoalsFor  GoalsAgainst Champion       ...        Third Fourth  \
# Pos                                                  ...
# 1         563      5947          3140       33       ...            8      8
# 2         608      5900          3114       25       ...           12     12
# 3         775      4534          3309       10       ...           16      9
# 4         861      4398          3469        6       ...           10     11
# 5         920      4631          3700        8       ...           10      5
#
# ...

# %% [markdown]
# # Q6 Group teams based on their “Best position” and print the sum of their points for all positions (5 points)

# %%
df[['Team','Points','BestPosition']].groupby(['BestPosition','Team']).sum()
# Out:
#                                  Points
# BestPosition Team
# 1            Athletic Bilbao       3368
#              Atletico Madrid       3442
#              Barcelona             4262
#              Deportivo La Coruna   1814
#              Real Betis            1884
#              Real Madrid           4385
#              Real Sociedad         2573
#              Sevilla               2819
#              Valencia              3386
# 2            Las Palmas            1020
#              Racing Santander      1416
#              Sporting Gijon        1389
#              Villarreal             970
#              Zaragoza              2109
# 3            Arenas                 107
#              Espanyol              2792
#              Mallorca              1148
#              Oviedo                1174
# 4            Castellon              285
#              Celta Vigo            1789
#              Malaga                1314
#              Osasuna               1351
# ...
